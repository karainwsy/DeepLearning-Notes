# %% [markdown]
# ##### ***填充***
# ###### 由于卷积层会让输入的维度逐渐变小，所以当我们使用了深层的卷积时，就会导致输出的维度变小，而为了做更深的模型，我们就需要在输入图像的边缘填充元素（一般是0）。
# ![image.png](attachment:image.png)
#
# ###### 根据公式可以得出，我们一般将ph = kh-1, pw = kw-1，使得输入和输出有相同的高度和宽度
# ##### ***步幅***
# ###### 步幅（stride）是指每次滑动元素的距离，默认是1，不过这就会带来一些问题，比如输入的维度过大而我们要的输出很小，就会导致整个模型层数会很深，这时候就要增大步幅达到快速计算的目的。
# ![image-2.png](attachment:image-2.png)
# ##### 填充和步幅都是卷积层的超参数

# %%
# 填充
import torch 
from torch import nn

def comp_conv2d(conv2d, X):
    X = X.reshape((1, 1)+X.shape)
    Y = conv2d(X)
    return Y.reshape(Y.shape[2:])

conv2d = nn.Conv2d(1, 1, kernel_size=3, padding=1)
x = torch.rand(size=(8, 8))
comp_conv2d(conv2d, x).shape
# Out:
# torch.Size([8, 8])

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=(5, 3), padding=(2, 1))
comp_conv2d(conv2d, x).shape
# Out:
# torch.Size([8, 8])

# %%
# 步幅
conv2d = nn.Conv2d(1, 1, kernel_size=3, padding=1, stride=2)
comp_conv2d(conv2d, x).shape
# Out:
# torch.Size([4, 4])

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=(3, 5), padding=(0, 1), stride=(3, 4))
comp_conv2d(conv2d, x).shape
# Out:
# torch.Size([2, 2])
